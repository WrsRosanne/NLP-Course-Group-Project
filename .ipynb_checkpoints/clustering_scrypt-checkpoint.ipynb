# %% [markdown]
# # Cluster Implementation Scrypt

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np
from textblob import TextBlob

import sys
sys.path.append('.')
from functions.csv_cleaning import load_in, remove_links, remove_nan, clean_data
from functions.clustering import tf_idf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 14
#      12 sys.path.append('.')
#      13 from functions.csv_cleaning import load_in, remove_links, remove_nan, clean_data
# ---> 14 from functions.clustering import tf_idf
#
# ImportError: cannot import name 'tf_idf' from 'functions.clustering' (/Users/thefleok/Desktop/GitHub/NLP-Course-Group-Project/functions/clustering.py)

# %%
df_raw = load_in()
df_basic = clean_data(df_raw)

# %%
print("Length of the dataframe is " + str(len(df_basic)) + "\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print("Length of the dataframe is " + str(len(df_basic)) + "\n")
#
# NameError: name 'df_basic' is not defined

# %%
df_basic.head(3)
# Out:
#                   Song Title         Artist  \
# 0  The Battle Of New Orleans  Johnny Horton
# 1             Mack The Knife    Bobby Darin
# 2                Personality    Lloyd Price
#
#                                               Lyrics    Year
# 0   In 1814 we took a little trip Along with Colo...  1959.0
# 1  Oh the shark, babe Has such teeth, dear And he...  1959.0
# 2  Over and over I tried to prove my love to you ...  1959.0

# %%
df = df_raw.dropna(subset=['Release Date'])
df = df_raw.dropna(subset=['Lyrics'])

# %%
print(len(df))
df.head(1)
# Out:
# 6271
#                    Album                                          Album URL  \
# 0  Battle of New Orleans  https://genius.com/albums/Johnny-horton/Battle...
#
#           Artist Featured Artists  \
# 0  Johnny Horton               []
#
#                                               Lyrics  \
# 0   In 1814 we took a little trip Along with Colo...
#
#                                                Media  Rank Release Date  \
# 0  [{'native_uri': 'spotify:track:0dwpdcQkeZqpuoA...     1   1959-04-01
#
#                   Song Title  \
# 0  The Battle Of New Orleans
#
#                                             Song URL  \
# 0  https://genius.com/Johnny-horton-the-battle-of...
#
#                                              Writers    Year  \
# 0  [{'api_path': '/artists/561913', 'header_image...  1959.0
#
#                                                Verbs  \
# 0  take take take catch fire keep be be fire begi...
#
#                                                Nouns  \
# 0  trip bacon bean town gun comin while river of'...
#
#                                              Adverbs  \
# 0  along as ago once more so as ago once more the...
#
#                                               Corpus  Word Counts  \
# 0  take little trip Colonel Jackson mighty Missis...          435
#
#    Unique Word Counts
# 0                 155

# %%
# 
vectorizer = TfidfVectorizer(max_features=10, stop_words='english',token_pattern=r'\b[a-zA-Z]{3,}\b')
tfidf_matrix = vectorizer.fit_transform(df['Lyrics'])
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), 
                        columns=vectorizer.get_feature_names_out())
print(len(tfidf_df))
tfidf_df.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 #
#       2 vectorizer = TfidfVectorizer(max_features=10, stop_words='english',token_pattern=r'\b[a-zA-Z]{3,}\b')
# ----> 3 tfidf_matrix = vectorizer.fit_transform(df['Lyrics'])
#       4 tfidf_df = pd.DataFrame(tfidf_matrix.toarray(),
#       5                         columns=vectorizer.get_feature_names_out())
#       6 print(len(tfidf_df))
#
# NameError: name 'df' is not defined

# %%
def get_sentiment(lyrics):
    blob = TextBlob(lyrics)
    return blob.sentiment.polarity  # Returns -1 (negative) to 1 (positive)

df['sentiment'] = df['Lyrics'].apply(get_sentiment)
df['subjectivity'] = df['Lyrics'].apply(lambda x: TextBlob(x).sentiment.subjectivity)
df.head(1)
# Out:
#                                  Album  \
# 0                Battle of New Orleans
# 1                           That’s All
# 2       “Mr Personality’s” 15 Big Hits
# 3  The Greatest Hits Of Frankie Avalon
# 4           Paul Anka Sings His Big 15
#
#                                            Album URL          Artist  \
# 0  https://genius.com/albums/Johnny-horton/Battle...   Johnny Horton
# 1   https://genius.com/albums/Bobby-darin/That-s-all     Bobby Darin
# 2  https://genius.com/albums/Lloyd-price/Mr-perso...     Lloyd Price
# 3  https://genius.com/albums/Frankie-avalon/The-g...  Frankie Avalon
# 4  https://genius.com/albums/Paul-anka/Paul-anka-...       Paul Anka
#
#   Featured Artists                                             Lyrics  \
# 0               []   In 1814 we took a little trip Along with Colo...
# 1               []  Oh the shark, babe Has such teeth, dear And he...
# 2               []  Over and over I tried to prove my love to you ...
# 3               []  Hey, Venus! Oh, Venus!  Venus, if you will Ple...
# 4               []  I'm just a lonely boy Lonely and blue I'm all ...
#
#                                                Media  Rank Release Date  \
# 0  [{'native_uri': 'spotify:track:0dwpdcQkeZqpuoA...     1   1959-04-01
# 1  [{'native_uri': 'spotify:track:3E5ndyOfO6vFDEI...     2          NaN
# 2  [{'provider': 'youtube', 'start': 0, 'type': '...     3          NaN
# 3                                                 []     4          NaN
# 4                                                 []     5          NaN
#
#                   Song Title  \
# 0  The Battle Of New Orleans
# 1             Mack The Knife
# 2                Personality
# 3                      Venus
# 4                 Lonely Boy
#
#                                             Song URL  \
# 0  https://genius.com/Johnny-horton-the-battle-of...
# 1  https://genius.com/Bobby-darin-mack-the-knife-...
# 2  https://genius.com/Lloyd-price-personality-lyrics
# 3     https://genius.com/Frankie-avalon-venus-lyrics
# 4     https://genius.com/Paul-anka-lonely-boy-lyrics
#
#                                              Writers    Year  \
# 0  [{'api_path': '/artists/561913', 'header_image...  1959.0
# 1  [{'api_path': '/artists/218851', 'header_image...  1959.0
# 2  [{'api_path': '/artists/355804', 'header_image...  1959.0
# 3  [{'api_path': '/artists/1113175', 'header_imag...  1959.0
# 4                                                 []  1959.0
#
#                                                Verbs  \
# 0  take take take catch fire keep be be fire begi...
# 1  have show have keep know bite billow spread be...
# 2  try prove do say get get do cause get get do s...
# 3  send thrill want make take place ask promise g...
# 4  do get think want love love kiss hold like hea...
#
#                                                Nouns  \
# 0  trip bacon bean town gun comin while river of'...
# 1  shark babe tooth jackknife babe sight shark to...
# 2  love friend fool fool personality personality ...
# 3  girl girl kiss arm girl charm girl sunlight ha...
# 4  boy nothing moment love night day boy nothing ...
#
#                                              Adverbs  \
# 0  along as ago once more so as ago once more the...
# 1  pearly just so never never now just just down ...
# 2  over over over over over over so over now over...
# 3  surely too always as long surely too always as...
# 4            just all just all just so hard just all
#
#                                               Corpus  Word Counts  \
# 0  take little trip Colonel Jackson mighty Missis...          435
# 1  oh shark babe tooth dear show pearly white jac...          224
# 2  try prove love friend say fool fool cause get ...          215
# 3  hey Venus oh Venus Venus send little girl thri...          166
# 4  lonely boy lonely blue get think want love yes...          140
#
#    Unique Word Counts  sentiment  subjectivity
# 0                 155   0.066681      0.391962
# 1                 145  -0.008757      0.219392
# 2                  55   0.433333      0.436111
# 3                  74   0.374312      0.614620
# 4                  68   0.141667      0.537745

# %%
pd.concat(tfidf_df, df[['sentiment', 'subjectivity', 'Year', 'Word Counts', 'Unique Word Counts','Rank']]
